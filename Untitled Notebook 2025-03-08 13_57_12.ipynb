# %%
# %python
configs = {
    "fs.azure.account.auth.type": "OAuth",
    "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
    "fs.azure.account.oauth2.client.id": "c95881ff-f483-4d9e-9e7a-8b49e6d279be",
    "fs.azure.account.oauth2.client.secret": dbutils.secrets.get(scope="akn1", key="secret"),
    "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/b668d6df-f625-425d-83fd-63397982e5a5/oauth2/token"
}

dbutils.fs.mount(
    source="abfss://raw@azureprc.dfs.core.windows.net/",
    mount_point="/mnt/raw",
    extra_configs=configs
)

# Refresh mounts to ensure the new mount point is available
dbutils.fs.refreshMounts()

# %%
display(dbutils.fs.ls("/mnt/raw"))
